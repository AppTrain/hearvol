# %%
heartvol = read.csv('train.csv')

# %%
#generates normal dist same size as heart records.

# %%
norm_samp = rnorm(nrow(heartvol))

# %%
qqnorm(norm_samp) # plots generated sample above against the Standard Normal Distribution

# %%
qqnorm(heartvol$Systole)

# %%
qqnorm(heartvol$Diastole)
abline(270,100,col='grey')

# %%
dbinom(1,1,.5) #  Binomial Probability, returns odds of success 'heads' of a single 'coin flip'
# Out:
# [1] 0.5

# %%
dbinom(2,4,.5) #  Probablity of exactly 2 'heads' in 4 coin flips (which means we also got exacty 2 tails)
# Out:
# [1] 0.375

# %%
dbinom(4,4, .5) # Probability of 4  heads in a row ..
# Out:
# [1] 0.0625

# %%
dbinom(0,4, .5) # ... is the same as 4 tail in a row

# %%
2 * dbinom(3,4, .5) # 3 heads ... (plus chance of 3 tails (or 1 head))
# Out:
# [1] 0.5

# %%
2 * dbinom(3,4, .5) + 2 * dbinom(0,4, .5) # all outcomes besides the 'exactly 2 heads'
# Out:
# [1] 0.625

# %%
1 - .625 == dbinom(2,4,.5)  # Total probablility of exactly 2 heads OR not ... is One)
# Out:
# [1] TRUE

# %%
pbinom(2,4,.5) # probability of 2 or less 'heads' (cumulative probability)
# Out:
# [1] 0.6875

# %%
dbinom(0:4,4,.5)
# Out:
# [1] 0.0625 0.2500 0.3750 0.2500 0.0625

# %%
pbinom(0:4,4,.5)

# %%
plot(dbinom(0:4,4,.5))

# %%
4 * .5  #Expected outcome is the 'mean' (p*n), the most likely result

# %%
plot(dbinom(0:100,100,.5))

# %%
plot(pbinom(0:100,100,.5))

# %%
rpois(100,lambda=2) #Poisson Distribution

# %%
plot(rpois(100,lambda=2))
